# %%
# %cd ../
# Out:
# D:\Projects\EpiTB\tbdx23

# %%
from sim.core.obj import *
import pandas as pd

# %%
obj = load_objective('data/pars/IND', 'results/pars_IND.csv')

for do in obj.Domain:
    print(do)

p0 = obj.sample_prior()
sim = obj.simulate(p0)
sim[1]
# Out:
# Inputs(Demography=<sim.core.inputs.Demography object at 0x000001D895374E50>, TxOut=Successful: 76%, LTFU: 21%, Die: 4%, TxOutHIV=None)
# Domain(Name='beta', Type='Double', Lower=1.0, Upper=20.0)
# Domain(Name='rr_sus_slat', Type='Double', Lower=0.2, Upper=0.8)
# Domain(Name='rr_sus_rec', Type='Double', Lower=0.14, Upper=0.31)
# Domain(Name='r_clear', Type='Double', Lower=0.02, Upper=0.04)
# Domain(Name='r_sc', Type='Double', Lower=0.15, Upper=0.25)
# Domain(Name='adr', Type='Double', Lower=-0.05, Upper=0.05)
#         IncR_apx  MorR_apx      IncR      MorR      DetR       CNR     PrLat  \
# Time
# 2014.0  0.008675  0.001371  0.008679  0.001371  0.005274  0.003719  0.738880
# 2015.0  0.008469  0.001297  0.008472  0.001297  0.005315  0.003748  0.737884
# 2016.0  0.008230  0.001221  0.008232  0.001221  0.005314  0.003747  0.736059
# 2017.0  0.007965  0.001142  0.007966  0.001142  0.005276  0.003720  0.733373
# 2018.0  0.007682  0.001064  0.007683  0.001064  0.005206  0.003671  0.729837
# 2019.0  0.007388  0.000987  0.007389  0.000986  0.005110  0.003603  0.725492
# 2020.0  0.007090  0.000912  0.007089  0.000912  0.004993  0.003521  0.720379
# 2021.0  0.006791  0.000841  0.006790  0.000841  0.004859  0.003426  0.714543
#
#         PrRecent      Prev
# Time
# 2014.0  0.922145  0.014884
# 2015.0  0.919964  0.014215
# 2016.0  0.917428  0.013500
# 2017.0  0.914573  0.012758
# 2018.0  0.911435  0.012005
# 2019.0  0.908047  0.011257
# 2020.0  0.904438  0.010526
# 2021.0  0.900643  0.009822

# %%
def fn():
    p0 = obj.sample_prior()
    _, ms, _ = obj.simulate(p0)


# %timeit fn()
# Out:
# 612 ms ± 52.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %prun fn()

# %%
# Out:
#         IncR_apx  MorR_apx      IncR      MorR      DetR       CNR     PrLat  \
# Time
# 2014.0  0.041233  0.007103  0.041239  0.007105  0.024033  0.020353  0.902720
# 2015.0  0.040092  0.006936  0.040096  0.006937  0.023480  0.019885  0.901952
# 2016.0  0.038893  0.006758  0.038897  0.006759  0.022872  0.019369  0.900942
# 2017.0  0.037648  0.006569  0.037651  0.006571  0.022222  0.018819  0.899688
# 2018.0  0.036363  0.006372  0.036365  0.006373  0.021540  0.018242  0.898167
# 2019.0  0.035043  0.006166  0.035045  0.006167  0.020832  0.017642  0.896371
# 2020.0  0.033693  0.005955  0.033695  0.005955  0.020103  0.017025  0.894265
# 2021.0  0.032316  0.005737  0.032318  0.005738  0.019354  0.016391  0.891811
#
#         PrRecent      Prev
# Time
# 2014.0  0.988102  0.060550
# 2015.0  0.987398  0.059072
# 2016.0  0.986631  0.057474
# 2017.0  0.985795  0.055776
# 2018.0  0.984887  0.054010
# 2019.0  0.983899  0.052183
# 2020.0  0.982824  0.050305
# 2021.0  0.981652  0.048377
