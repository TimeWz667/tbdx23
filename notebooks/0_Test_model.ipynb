# %%
# %cd ../
# Out:
# D:\Source\tbdx23

# %%
from sim.core.obj import *
import pandas as pd

# %%
obj = load_objective('data/pars/IND', 'results/pars_IND.csv')

for do in obj.Domain:
    print(do)

p0 = obj.sample_prior()
sim = obj.simulate(p0)
sim[1]
# Out:
# Domain(Name='beta', Type='Double', Lower=1.0, Upper=20.0)
# Domain(Name='rr_sus_slat', Type='Double', Lower=0.2, Upper=0.8)
# Domain(Name='rr_sus_rec', Type='Double', Lower=0.14, Upper=0.31)
# Domain(Name='r_clear', Type='Double', Lower=0.02, Upper=0.04)
# Domain(Name='r_sc', Type='Double', Lower=0.15, Upper=0.25)
# Domain(Name='adr', Type='Double', Lower=0.0, Upper=0.05)
#          IncR_apx  MorR_apx   CNR_apx        CumInc        CumMor      IncR  \
# Time
# 2014.00  0.017047  0.002409  0.007984  7.067669e+09  9.577068e+08  0.012787
# 2014.75  0.016510  0.002347  0.007946  7.084135e+09  9.600411e+08  0.012384
# 2015.50  0.015949  0.002281  0.007972  7.100193e+09  9.623311e+08  0.011963
# 2016.25  0.015371  0.002211  0.008116  7.115814e+09  9.645714e+08  0.011529
# 2017.00  0.014785  0.002137  0.008433  7.130973e+09  9.667569e+08  0.011089
# 2017.75  0.014195  0.002060  0.008963  7.145654e+09  9.688835e+08  0.010646
# 2018.50  0.013607  0.001983  0.009705  7.159847e+09  9.709476e+08  0.010204
# 2019.25  0.013024  0.001905  0.010592  7.173544e+09  9.729475e+08  0.009767
#
#              MorR      DetR       CNR     PrLat  PrRecent      Prev     PrevA  \
# Time
# 2014.00  0.001807  0.007862  0.005984  0.869744  0.957699  0.027290  0.014496
# 2014.75  0.001761  0.007675  0.005955  0.867059  0.956111  0.026579  0.014096
# 2015.50  0.001711  0.007463  0.005973  0.863890  0.954370  0.025806  0.013664
# 2016.25  0.001658  0.007233  0.006076  0.860253  0.952484  0.024979  0.013209
# 2017.00  0.001603  0.006992  0.006310  0.856155  0.950453  0.024115  0.012739
# 2017.75  0.001545  0.006743  0.006707  0.851605  0.948282  0.023230  0.012260
# 2018.50  0.001487  0.006492  0.007274  0.846615  0.945970  0.022339  0.011776
# 2019.25  0.001429  0.006230  0.007940  0.841205  0.943525  0.021438  0.011294
#
#             PrevS     PrevC
# Time
# 2014.00  0.004689  0.004122
# 2014.75  0.004567  0.004023
# 2015.50  0.004434  0.003911
# 2016.25  0.004292  0.003792
# 2017.00  0.004144  0.003666
# 2017.75  0.003993  0.003536
# 2018.50  0.003839  0.003401
# 2019.25  0.003684  0.003268

# %%
def fn():
    p0 = obj.sample_prior()
    _, ms, _ = obj.simulate(p0)


# %timeit fn()
# Out:
# 334 ms ± 24.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %prun fn()

# %%
# Out:
#         IncR_apx  MorR_apx      IncR      MorR      DetR       CNR     PrLat  \
# Time
# 2014.0  0.041233  0.007103  0.041239  0.007105  0.024033  0.020353  0.902720
# 2015.0  0.040092  0.006936  0.040096  0.006937  0.023480  0.019885  0.901952
# 2016.0  0.038893  0.006758  0.038897  0.006759  0.022872  0.019369  0.900942
# 2017.0  0.037648  0.006569  0.037651  0.006571  0.022222  0.018819  0.899688
# 2018.0  0.036363  0.006372  0.036365  0.006373  0.021540  0.018242  0.898167
# 2019.0  0.035043  0.006166  0.035045  0.006167  0.020832  0.017642  0.896371
# 2020.0  0.033693  0.005955  0.033695  0.005955  0.020103  0.017025  0.894265
# 2021.0  0.032316  0.005737  0.032318  0.005738  0.019354  0.016391  0.891811
#
#         PrRecent      Prev
# Time
# 2014.0  0.988102  0.060550
# 2015.0  0.987398  0.059072
# 2016.0  0.986631  0.057474
# 2017.0  0.985795  0.055776
# 2018.0  0.984887  0.054010
# 2019.0  0.983899  0.052183
# 2020.0  0.982824  0.050305
# 2021.0  0.981652  0.048377
